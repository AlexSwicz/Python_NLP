# %%
import gensim
import json
import re
from nltk.tokenize import word_tokenize
from pymorphy2 import MorphAnalyzer
import pyLDAvis.gensim 
from nltk.corpus import stopwords
morph = MorphAnalyzer()
# Out:
# C:\Users\asus\AppData\Local\Continuum\anaconda3\lib\site-packages\gensim\utils.py:1197: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %%
import warnings
import numpy as np

# %% [markdown]
# ## Домашнее задание

# %% [markdown]
# Основаная задача - **построить хорошую тематическую модель с интерпретируемыми топиками**.
#
# 1) сделайте нормализацию (если pymorphy2 работает долго используйте mystem или попробуйте установить быструю версию - `pip install pymorphy2[fast]`, можно использовать какой-то другой токенизатор);
#
# 2) добавьте нграммы (в тетрадке есть закомменченая ячейка с Phrases);
#
# 3) сделайте хороший словарь (отфильтруйте слишком частотные и редкие слова, попробуйте удалить стоп-слова);
#
# 4) постройте несколько LDA моделей (переберите количество тем, можете поменять eta, alpha, passes), если получаются плохие темы, поработайте дополнительно над предобработкой и словарем;
#
# 5) для самой хорошей модели в отдельной ячейке напечатайте 3 хороших (на ваш вкус) темы;
#
# 6) между словарем и обучением модели добавьте tfidf (`gensim.models.TfidfModel(corpus, id2word=dictionary); corpus = tfidf[corpus]`);
#
# 7) заново обучите LDA c теми же параметрами (параметрами самой лучшей модели, заново перебирать не нужно);
#
# 8) в отдельной ячейке опишите как изменилась модель (приведите несколько тем, которые стали лучше или хуже, или которых раньше вообще не было; можно привести значения перплексии и когерентности для обеих моделей)
#
# 9) проделайте такие же действия для NMF (образец в конце тетрадки), для построения словаря воспользуйтесь возможностями Count или Tfidf Vectorizer (попробуйте другие значение max_features, min_df, max_df, сделайте нграмы через ngram_range, если хватает памяти), попробуйте такие же количества тем
#
# 10) в отдельной ячейки напечатайте таблицу с темами лучшей NMF модели, сравните их с теми, что получились в LDA.
#
# Сохраните тетрадку с экспериментами и положите её на гитхаб, ссылку на неё укажите в форме.
#
# **Оцениваться будут главным образом пункты 5, 8 и 10. (2, 3, 2 баллов соответственно). Чтобы заработать остальные 3 балла, нужно хотя бы немного изменить мой код на промежуточных этапах (добавить что-то, указать другие параметры и т.д). **

# %% [markdown]
# ## Данные

# %%
def remove_tags(texts):
    return [re.sub(r'{[*]}+>', '', text) for text in texts]
#В очистке мне интересно было посмотреть, как он разобъёт текст на темы, не имея подсказок в виде терминологии на английском
#Прошу прощения за длинный и топорный код по склейкам-очисткам
def clean(words):
    stp = stopwords.words('russian')
    words = [word.lower() for word in words]
    lst = []
    wrds = [re.findall('[а-я]+', word) for word in words]
    for wrd in wrds:
        lst2 = []
        for wd in wrd:
            if wd not in stp:
                lst2.append(wd)
        xx = ' '.join(lst2)
        lst.append(xx)
    clean = [morph.parse(word)[0].normal_form for word in lst if len(set(word)) > 1]
    return clean

# %% [markdown]
# Возьмем 4 тыс статьи с Хабра. Это мало для хорошей тематической модели, но иначе у нас просто ничего не обучится за семинар.

# %%
texts = open('habr_texts.txt', encoding = 'utf-8').read().splitlines()

# %% [markdown]
# В текстах есть тэги. Потрем их. Ещё токенизируем самым простым способом и нормализуем Pymorphy.

# %%
texts = [clean(word_tokenize(text.lower())) for text in texts]

# %%
print(len(texts))
# Out:
# 4121

# %%
from collections import Counter

# %%
allwords = []
for x in texts:
    for i in x:
        allwords.append(i)
print(len(allwords))
# Out:
# 2962789

# %%
x = Counter(allwords).most_common()
print(x[:50])
# Out:
# [('это', 36098), ('который', 33128), ('один', 17493), ('дать', 16024), ('такой', 12884), ('год', 12621), ('время', 12051), ('использовать', 11970), ('мочь', 11509), ('работа', 11410), ('система', 10929), ('свой', 10128), ('работать', 9632), ('самый', 9428), ('наш', 8940), ('компания', 8680), ('другой', 8484), ('человек', 8417), ('код', 8253), ('каждый', 8235), ('проект', 7749), ('пользователь', 7654), ('очень', 7452), ('случай', 7271), ('быть', 7208), ('должный', 7087), ('нужно', 7064), ('также', 7062), ('приложение', 7006), ('сделать', 6739), ('например', 6724), ('тот', 6349), ('новый', 6306), ('несколько', 6258), ('функция', 6211), ('файл', 6079), ('возможность', 6060), ('проблема', 6056), ('просто', 6044), ('два', 6038), ('иметь', 6034), ('решение', 5983), ('делать', 5904), ('задача', 5902), ('получить', 5792), ('какой', 5784), ('стать', 5666), ('результат', 5656), ('игра', 5424), ('устройство', 5414)]

# %% [markdown]
# Если модель будет совсем плохо работать, попробуем добавить эти слова и сравнить качество.

# %%
# для нграммов
ph = gensim.models.Phrases(texts, scoring='npmi', threshold=0.4) # threshold можно подбирать
p = gensim.models.phrases.Phraser(ph)
ngrammed_texts = p[texts]

# %% [markdown]
# ### Тематическое моделирование в gensim

# %% [markdown]
# Для моделей нужно сделать словарь.

# %%
dictinary = gensim.corpora.Dictionary(texts)

# %%
dictinary.filter_extremes(no_above=0.3, no_below=30)
dictinary.compactify()

# %%
print(dictinary)
# Out:
# Dictionary(6408 unique tokens: ['распредел нный', 'клуб', 'глубоко', 'дизайн', 'каскад']...)

# %% [markdown]
# Преобразуем наши тексты в мешки слов.

# %%
corpus = [dictinary.doc2bow(text) for text in texts]

# %%
with warnings.catch_warnings():
    warnings.filterwarnings("ignore",category=DeprecationWarning)
    lda = gensim.models.LdaMulticore(corpus, 100, id2word=dictinary, passes=3)
# Out:
# C:\Users\asus\AppData\Local\Continuum\anaconda3\lib\site-packages\gensim\models\ldamodel.py:775: RuntimeWarning: divide by zero encountered in log
#   diff = np.log(self.expElogbeta)

# %%
with warnings.catch_warnings():
    warnings.filterwarnings("ignore",category=DeprecationWarning)
    lda2 = gensim.models.LdaMulticore(corpus, 50, id2word=dictinary, passes=3)
    lda3 = gensim.models.LdaMulticore(corpus, 20, id2word=dictinary, passes=3)

# %%
with warnings.catch_warnings():
    warnings.filterwarnings("ignore",category=DeprecationWarning)
    print('Перплексия на 100 темах: ', lda.log_perplexity(corpus[:2000], total_docs=100))
    print('Перплексия на 50 темах: ', lda2.log_perplexity(corpus[:2000], total_docs=100))
    print('Перплексия на 20 темах: ', lda3.log_perplexity(corpus[:2000], total_docs=100))
# Out:
# Перплексия на 100 темах:  -46.17318780129595
# Перплексия на 50 темах:  -26.942996425054794
# Перплексия на 20 темах:  -15.138136292876991

# %% [markdown]
# Теперь посмотрим когерентность.

# %%
#with warnings.catch_warnings():
#    warnings.filterwarnings("ignore",category=DeprecationWarning)
print('Когерентность на 100 темах: ', gensim.models.CoherenceModel(model=lda, texts=texts, dictionary=dictinary, coherence='c_v').get_coherence())
print('Когерентность на 50 темах: ', gensim.models.CoherenceModel(model=lda2, texts=texts, dictionary=dictinary, coherence='c_v').get_coherence())
print('Когерентность на 20 темах: ', gensim.models.CoherenceModel(model=lda3, texts=texts, dictionary=dictinary, coherence='c_v').get_coherence())
# Out:
# Когерентность на 100 темах:  0.3787498612403591
# Когерентность на 50 темах:  0.4172323433408818
# Когерентность на 20 темах:  0.37048508507885325

# %% [markdown]
# Хотя лучшая перплексия на ста темах, лучшая когерентность на 50-ти. Как найти баланс? Попробуем еще 35 тем.

# %%
with warnings.catch_warnings():
    warnings.filterwarnings("ignore",category=DeprecationWarning)
    lda4 = gensim.models.LdaMulticore(corpus, 35, id2word=dictinary, passes=3)
    print('Перплексия на 35 темах: ', lda4.log_perplexity(corpus[:2000], total_docs=100))
    print('Когерентность на 35 темах: ', gensim.models.CoherenceModel(model=lda4, texts=texts, dictionary=dictinary, coherence='c_v').get_coherence())
# Out:
# Перплексия на 35 темах:  -21.063387398149874
# Когерентность на 35 темах:  0.3956190116257626

# %% [markdown]
# Пожалуй, остановимся на этом как на сбалансированном варианте.

# %% [markdown]
# Посмотрим на топики.

# %%
lda4.print_topics()
# Out:
# [(4,
#   '0.012*"элемент" + 0.010*"компонент" + 0.010*"класс" + 0.006*"метод" + 0.006*"тест" + 0.005*"список" + 0.005*"свойство" + 0.005*"библиотека" + 0.005*"строка" + 0.004*"значение"'),
#  (20,
#   '0.006*"тест" + 0.004*"диск" + 0.004*"операция" + 0.004*"устройство" + 0.004*"глаз" + 0.003*"тестирование" + 0.003*"лазер" + 0.003*"метод" + 0.002*"пациент" + 0.002*"лицо"'),
#  (17,
#   '0.006*"клиент" + 0.004*"сайт" + 0.004*"продукт" + 0.003*"ошибка" + 0.003*"атака" + 0.003*"сервис" + 0.003*"программа" + 0.003*"управление" + 0.002*"бизнес" + 0.002*"сообщение"'),
#  (2,
#   '0.013*"файл" + 0.010*"машина" + 0.009*"база" + 0.009*"резервный" + 0.007*"диск" + 0.006*"копирование" + 0.005*"устройство" + 0.005*"сервер" + 0.005*"копия" + 0.005*"виртуальный"'),
#  (15,
#   '0.005*"игра" + 0.004*"сайт" + 0.003*"программа" + 0.003*"элемент" + 0.003*"список" + 0.003*"доступ" + 0.003*"ещ" + 0.002*"деньга" + 0.002*"игрок" + 0.002*"обучение"'),
#  (10,
#   '0.007*"технология" + 0.006*"сеть" + 0.006*"устройство" + 0.004*"вирус" + 0.004*"производство" + 0.003*"интернет" + 0.003*"пациент" + 0.003*"безопасность" + 0.003*"сервис" + 0.003*"российский"'),
#  (1,
#   '0.007*"адрес" + 0.006*"маршрутизатор" + 0.005*"маршрут" + 0.005*"сеть" + 0.004*"клетка" + 0.003*"интерфейс" + 0.003*"данный" + 0.003*"ген" + 0.003*"днк" + 0.002*"устройство"'),
#  (18,
#   '0.007*"модуль" + 0.007*"устройство" + 0.005*"сеть" + 0.005*"уязвимость" + 0.004*"файл" + 0.003*"кабель" + 0.003*"принтер" + 0.003*"программа" + 0.003*"адрес" + 0.003*"безопасность"'),
#  (29,
#   '0.029*"игра" + 0.008*"игрок" + 0.004*"игровой" + 0.004*"ещ" + 0.003*"играть" + 0.002*"продукт" + 0.002*"рынок" + 0.002*"мой" + 0.002*"карта" + 0.002*"друг"'),
#  (5,
#   '0.013*"сервер" + 0.010*"сервис" + 0.007*"файл" + 0.006*"настройка" + 0.004*"сеть" + 0.004*"доступ" + 0.004*"камера" + 0.004*"клиент" + 0.004*"хост" + 0.004*"домен"'),
#  (14,
#   '0.007*"сервер" + 0.004*"сайт" + 0.004*"т е" + 0.004*"продукт" + 0.004*"запрос" + 0.003*"сертификат" + 0.003*"либо" + 0.003*"интерфейс" + 0.003*"точка" + 0.003*"клиент"'),
#  (3,
#   '0.008*"товар" + 0.005*"скидка" + 0.005*"объект" + 0.004*"программа" + 0.004*"сообщение" + 0.004*"база" + 0.004*"инструмент" + 0.004*"свет" + 0.003*"датчик" + 0.003*"цена"'),
#  (31,
#   '0.010*"устройство" + 0.005*"смартфон" + 0.005*"модель" + 0.003*"телефон" + 0.003*"цена" + 0.003*"рынок" + 0.003*"производитель" + 0.003*"часы" + 0.003*"технология" + 0.003*"рубль"'),
#  (8,
#   '0.006*"глаз" + 0.005*"файл" + 0.004*"язык" + 0.004*"компонент" + 0.003*"сайт" + 0.003*"анализатор" + 0.003*"сервер" + 0.003*"устройство" + 0.003*"технология" + 0.002*"программа"'),
#  (0,
#   '0.009*"сайт" + 0.007*"сотрудник" + 0.005*"продукт" + 0.005*"технология" + 0.004*"сеть" + 0.004*"мобильный" + 0.004*"сервис" + 0.004*"рынок" + 0.004*"деньга" + 0.004*"клиент"'),
#  (27,
#   '0.007*"файл" + 0.006*"язык" + 0.006*"ядро" + 0.004*"устройство" + 0.004*"инструмент" + 0.004*"поддержка" + 0.003*"платформа" + 0.003*"программа" + 0.003*"страница" + 0.003*"строка"'),
#  (32,
#   '0.006*"устройство" + 0.005*"страница" + 0.005*"сеть" + 0.004*"база" + 0.004*"инструмент" + 0.004*"тест" + 0.004*"технология" + 0.004*"ключ" + 0.004*"платформа" + 0.003*"инфраструктура"'),
#  (22,
#   '0.007*"экран" + 0.006*"модель" + 0.005*"игра" + 0.004*"изображение" + 0.004*"автомобиль" + 0.004*"объект" + 0.004*"кнопка" + 0.003*"дисплей" + 0.003*"устройство" + 0.003*"точка"'),
#  (23,
#   '0.005*"движение" + 0.005*"устройство" + 0.004*"камера" + 0.004*"сеть" + 0.003*"дом" + 0.003*"смартфон" + 0.003*"кнопка" + 0.003*"ручка" + 0.002*"ещ" + 0.002*"умный"'),
#  (9,
#   '0.010*"файл" + 0.008*"точка" + 0.008*"значение" + 0.007*"строка" + 0.007*"пакет" + 0.006*"элемент" + 0.005*"запрос" + 0.005*"таблица" + 0.005*"блок" + 0.005*"объект"')]

# %% [markdown]
# <b>Первая</b> тема, которая мне показалась неплохой, явно про коммерческую разработку: '0.006*"клиент" + 0.004*"сайт" + 0.004*"продукт" + 0.003*"ошибка" + 0.003*"атака" + 0.003*"сервис" + 0.003*"программа" + 0.003*"управление" + 0.002*"бизнес" + 0.002*"сообщение"'.
# <b>Вторая</b> неплохо выглядящая тема - что-то про компьютерную безопасность: '0.007*"технология" + 0.006*"сеть" + 0.006*"устройство" + 0.004*"вирус" + 0.004*"производство" + 0.003*"интернет" + 0.003*"пациент" + 0.003*"безопасность" + 0.003*"сервис" + 0.003*"российский"'.
# <b>Третья</b> хорошая тема - тема про игры: '0.029*"игра" + 0.008*"игрок" + 0.004*"игровой" + 0.004*"ещ" + 0.003*"играть" + 0.002*"продукт" + 0.002*"рынок" + 0.002*"мой" + 0.002*"карта" + 0.002*"друг"'.

# %%
dictinary = gensim.corpora.Dictionary(texts)
dictinary.filter_extremes(no_above=0.3, no_below=30)
dictinary.compactify()
print(dictinary)
# Out:
# Dictionary(6408 unique tokens: ['распредел нный', 'клуб', 'глубоко', 'дизайн', 'каскад']...)

# %%
tfidf = gensim.models.TfidfModel(corpus, id2word=dictinary)
corpus = tfidf[corpus]

# %%
with warnings.catch_warnings():
    warnings.filterwarnings("ignore",category=DeprecationWarning)
    lda5 = gensim.models.LdaMulticore(corpus, 35, id2word=dictinary, passes=3)

# %%
with warnings.catch_warnings():      
    warnings.filterwarnings("ignore",category=DeprecationWarning)
    print('Перплексия на 35 темах: ', lda5.log_perplexity(corpus[:2000], total_docs=100))
    print('Когерентность на 35 темах: ', gensim.models.CoherenceModel(model=lda5, texts=texts, dictionary=dictinary, coherence='c_v').get_coherence())
# Out:
# Перплексия на 35 темах:  -131.76430775205964
# Когерентность на 35 темах:  0.3011050895655429

# %% [markdown]
# Перплексия неожиданно стала очень низкой, зато когерентность сильно упала.

# %%
lda5.print_topics()
# Out:
# [(11,
#   '0.002*"пост" + 0.002*"удалённый" + 0.002*"локализация" + 0.002*"безопасность" + 0.001*"преступник" + 0.001*"улица" + 0.001*"собственность" + 0.001*"анимация" + 0.001*"устройство" + 0.001*"язык"'),
#  (22,
#   '0.004*"метка" + 0.002*"уравнение" + 0.001*"формула" + 0.001*"клиент" + 0.001*"класс" + 0.001*"пакет" + 0.001*"файл" + 0.001*"тег" + 0.001*"тест" + 0.001*"диаграмма"'),
#  (17,
#   '0.004*"резервный" + 0.003*"копирование" + 0.003*"скрипт" + 0.002*"вселенная" + 0.002*"бот" + 0.002*"виртуальный" + 0.002*"сервер" + 0.002*"восстановление" + 0.002*"файл" + 0.002*"вм"'),
#  (13,
#   '0.004*"файл" + 0.002*"сервер" + 0.002*"пакет" + 0.002*"тест" + 0.002*"модуль" + 0.002*"параметр" + 0.002*"клиент" + 0.002*"устройство" + 0.002*"порт" + 0.002*"адрес"'),
#  (23,
#   '0.003*"атака" + 0.002*"нейросеть" + 0.002*"значение" + 0.002*"элемент" + 0.002*"объект" + 0.002*"игра" + 0.002*"координата" + 0.002*"событие" + 0.002*"метод" + 0.002*"ячейка"'),
#  (30,
#   '0.002*"пакет" + 0.001*"протокол" + 0.001*"транзакция" + 0.001*"вебинар" + 0.001*"население" + 0.001*"устройство" + 0.001*"игра" + 0.001*"клиент" + 0.001*"дорога" + 0.001*"календарь"'),
#  (31,
#   '0.002*"задание" + 0.002*"тэг" + 0.002*"дерево" + 0.002*"скрипт" + 0.002*"запрос" + 0.001*"мастер" + 0.001*"файл" + 0.001*"раздел" + 0.001*"плоскость" + 0.001*"браузер"'),
#  (32,
#   '0.002*"шлюз" + 0.002*"проведение" + 0.001*"сервер" + 0.001*"треугольник" + 0.001*"файл" + 0.001*"мусор" + 0.001*"устройство" + 0.001*"декабрь" + 0.001*"кнопка" + 0.001*"песочница"'),
#  (2,
#   '0.002*"марс" + 0.002*"рак" + 0.001*"снимка" + 0.001*"кабель" + 0.001*"аккумулятор" + 0.001*"германия" + 0.001*"пациент" + 0.001*"батарея" + 0.001*"животное" + 0.001*"база"'),
#  (16,
#   '0.003*"вселенная" + 0.003*"телескоп" + 0.002*"модуль" + 0.002*"двигатель" + 0.002*"светов" + 0.002*"боль" + 0.002*"астроном" + 0.002*"болезнь" + 0.002*"галактика" + 0.002*"объект"'),
#  (27,
#   '0.003*"спутник" + 0.003*"плата" + 0.003*"автомобиль" + 0.002*"лазер" + 0.002*"сигнал" + 0.002*"процессор" + 0.002*"операция" + 0.002*"ядро" + 0.002*"файл" + 0.002*"устройство"'),
#  (7,
#   '0.003*"локализация" + 0.003*"частица" + 0.002*"свойство" + 0.002*"объект" + 0.002*"объектив" + 0.002*"значение" + 0.001*"квантовый" + 0.001*"криптография" + 0.001*"метод" + 0.001*"локализовать"'),
#  (5,
#   '0.003*"модуль" + 0.002*"класс" + 0.002*"плеер" + 0.002*"уязвимость" + 0.002*"устройство" + 0.002*"звук" + 0.002*"файл" + 0.002*"сокет" + 0.002*"директория" + 0.002*"сервер"'),
#  (19,
#   '0.003*"таймер" + 0.003*"матрица" + 0.002*"корея" + 0.002*"сетка" + 0.002*"градиент" + 0.002*"датчик" + 0.002*"кб" + 0.002*"вектор" + 0.001*"сеть" + 0.001*"библиотека"'),
#  (3,
#   '0.003*"файл" + 0.002*"услуга" + 0.002*"индекс" + 0.001*"интерпретатор" + 0.001*"пароль" + 0.001*"шифрование" + 0.001*"велосипед" + 0.001*"запрос" + 0.001*"сервер" + 0.001*"получатель"'),
#  (9,
#   '0.002*"сервер" + 0.002*"блок" + 0.002*"сертификат" + 0.002*"исходник" + 0.002*"заказчик" + 0.002*"слот" + 0.002*"действующий" + 0.001*"файл" + 0.001*"след" + 0.001*"устройство"'),
#  (10,
#   '0.007*"станок" + 0.002*"программа" + 0.002*"кофе" + 0.002*"страница" + 0.002*"сертификат" + 0.002*"робот" + 0.002*"класс" + 0.001*"файл" + 0.001*"андрей" + 0.001*"запись"'),
#  (28,
#   '0.002*"язык" + 0.001*"класс" + 0.001*"объект" + 0.001*"метод" + 0.001*"устройство" + 0.001*"продукт" + 0.001*"сообщение" + 0.001*"бот" + 0.001*"сайт" + 0.001*"сеть"'),
#  (4,
#   '0.003*"файл" + 0.002*"браузер" + 0.002*"загрузчик" + 0.002*"репозиторий" + 0.002*"лёд" + 0.002*"библиотека" + 0.002*"стек" + 0.002*"расширение" + 0.002*"компонент" + 0.002*"скрипт"'),
#  (29,
#   '0.011*"игра" + 0.005*"игрок" + 0.003*"игровой" + 0.002*"квантовый" + 0.002*"мозг" + 0.002*"реклама" + 0.002*"лекция" + 0.002*"мобильный" + 0.002*"рынок" + 0.002*"сайт"')]

# %% [markdown]
# Забавно: хотя сохранились разные бизнес-темы и технологии, неожиданно совсем ушла тема про вирусы (точнее тема про безопасность несколько изменилась). В первой модели слово "элемент" явно играло большую роль: особенно хорошо это было в 4 теме, где явно описывались какие-то языки программирования или что-то подобное; во второй модели эта ярко выраженная тема вроде бы вовсе пропадает. Также пропадает и 20-я тема про тестирование, точнее расходится по другим темам; полностью пропадает 3 тема (про товар).

# %%
from sklearn.decomposition import NMF
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
import pandas as pd

# %%
stexts = [' '.join(text) for text in texts]

# %%
print(len(stexts))
# Out:
# 4121

# %%
vectorizer = TfidfVectorizer(max_features=35000, min_df=4, max_df=0.3, lowercase=False)
X = vectorizer.fit_transform(stexts)

# %%
model1 = NMF(n_components=100)
model1.fit(X)
def get_nmf_topics(model, n_top_words):
    
    #id слов.
    feat_names = vectorizer.get_feature_names()
    
    word_dict = {};
    for i in range(100):
        
        #топ n слов для темы.
        words_ids = model1.components_[i].argsort()[:-n_top_words - 1:-1]
        words = [feat_names[key] for key in words_ids]
        word_dict['Topic # ' + '{:02d}'.format(i+1)] = words;
    
    return pd.DataFrame(word_dict);
get_nmf_topics(model1, 10)
# Out:
#        Topic # 01    Topic # 02 Topic # 03    Topic # 04   Topic # 05  \
# 0          бизнес       продукт       игра        сервер     смартфон
# 1        заказчик       битрикс    игровой     настройка      дисплей
# 2              ит         рынок     играть      выделить        экран
# 3      управление    функционал     движок         адрес      ноутбук
# 4    планирование     платформа  приставка      нагрузка  аккумулятор
# 5     технический      менеджер       жанр  конфигурация           гб
# 6     исполнитель       продакт       инди       хостинг      планшет
# 7      архитектор     конкурент   персонаж          порт   клавиатура
# 8          услуга  тестирование  выпустить           веб     дюймовый
# 9  инфраструктура          идея    автомат          база       корпус
#
#      Topic # 06   Topic # 07          Topic # 08      Topic # 09  Topic # 10  \
# 0         класс         марс              память           атака      запрос
# 1         метод  космический         оперативный    безопасность       ответ
# 2    реализация      станция                  гб          защита  выполнение
# 3         вызов      аппарат  производительность          ботнет         кэш
# 4     интерфейс         луна                  мб   злоумышленник      сессия
# 5   реализовать         наса          накопитель     вредоносный      строка
# 6     экземпляр       миссия         потребление          угроза    параметр
# 7      свойство       космос                 объ           хакер        субд
# 8  наследование        полёт                субд  информационный   получение
# 9      параметр        земля               поток           взлом      ошибка
#
#       ...           Topic # 90   Topic # 91    Topic # 92        Topic # 93  \
# 0     ...           российский     анимация         видео       регистратор
# 1     ...                закон         кадр          пост             видео
# 2     ...               россия     движение  рассказывать         китайский
# 3     ...                   рф  анимировать   комментарий            запись
# 4     ...                  фас     персонаж      обсудить             рубль
# 5     ...               страна        экран         хабра           глонасс
# 6     ...         роскомнадзор         слой   публиковать  видеорегистратор
# 7     ...                  суд     нативный        удобно            модель
# 8     ...           блокировка       спрайт       слушать             бренд
# 9     ...      государственный       эффект      делиться           матрица
#
#   Topic # 94  Topic # 95 Topic # 96  Topic # 97     Topic # 98  Topic # 99
# 0     символ      плагин      лазер       карта      сотрудник     регистр
# 1     строка      иконка   роговица      платёж           офис       адрес
# 2      шрифт         веб       глаз       банка        рабочий        байт
# 3      текст    редактор   операция        банк       работник       битый
# 4      буква   настройка    пациент   платёжный   руководитель  инструкция
# 5    дисплей   установка     хирург      оплата       менеджер        порт
# 6    таблица  инструмент      линза  банковский  корпоративный        флаг
# 7       глиф    название  коррекция        шлюз         отпуск      таймер
# 8      цифра       поиск     разрез    терминал      удалённый    значение
# 9  кодировка        билд  лентикула      страна       зарплата  прерывание
#
# [10 rows x 100 columns]

# %% [markdown]
# Беглый взгляд видит те же темы, что и раньше - бизнес, продукты, игры, серверы, смартфоны, космос, память (в связи с серверами?), компбез, современные технологии и т.д. Вроде бы все слова более-мееее подходят друг к другу, но темы очень узкоспециализированные.

# %%
model2 = NMF(n_components=50)
model2.fit(X)
def get_nmf_topics(model, n_top_words):
    
    #id слов.
    feat_names = vectorizer.get_feature_names()
    
    word_dict = {};
    for i in range(50):
        
        #топ n слов для темы.
        words_ids = model2.components_[i].argsort()[:-n_top_words - 1:-1]
        words = [feat_names[key] for key in words_ids]
        word_dict['Topic # ' + '{:02d}'.format(i+1)] = words;
    
    return pd.DataFrame(word_dict);
get_nmf_topics(model2, 10)
# Out:
#     Topic # 01  Topic # 02 Topic # 03    Topic # 04   Topic # 05   Topic # 06  \
# 0    сотрудник  российский       игра        сервер     смартфон        класс
# 1  программист       рынок      игрок         адрес      телефон       объект
# 2          мой      россия    игровой         домен      дисплей        метод
# 3       деньга       рубль     играть     настройка        экран        вызов
# 4        жизнь      страна   персонаж      выделить  аккумулятор   реализация
# 5         опыт       налог     движок       хостинг      ноутбук     свойство
# 6       бизнес     миллион   геймплей      нагрузка           гб    экземпляр
# 7           ещ       доход  приставка  конфигурация       модель    интерфейс
# 8       думать       закон       жанр       кластер      батарея  реализовать
# 9         идея      бизнес       инди          база       корпус     значение
#
#     Topic # 07     Topic # 08      Topic # 09  Topic # 10       ...        \
# 0         марс    виртуальный           атака      запрос       ...
# 1        земля         машина    безопасность     таблица       ...
# 2         луна             вм          защита        база       ...
# 3      аппарат           хост     вредоносный          бд       ...
# 4      планета     реальность   злоумышленник      индекс       ...
# 5  космический  виртуализация          ботнет        субд       ...
# 6     астероид    гипервизора          угроза      запись       ...
# 7      станция             ос           хакер      строка       ...
# 8    солнечный     автомобиль       программа       ответ       ...
# 9       орбита        сетевой  информационный  выполнение       ...
#
#        Topic # 41   Topic # 42    Topic # 43  Topic # 44   Topic # 45  \
# 0            диск     текстура       продукт   компонент    сообщение
# 1       резервный  изображение     мобильный  компонента       сервис
# 2           бэкап        карта        дизайн   состояние     отправка
# 3           копия     анимация         рынок  библиотека      событие
# 4     копирование       шейдёр    инструмент    свойство        канал
# 5  восстановление      пиксель     платформа   рендеринг   отправлять
# 6          запись        точка      дизайнер     событие  уведомление
# 7             схд       объект     интерфейс      шаблон         байт
# 8        хранение   координата        сервис  отображать    отправить
# 9            база         свет  тестирование   отрисовка      очередь
#
#    Topic # 46   Topic # 47  Topic # 48          Topic # 49      Topic # 50
# 0      клиент       письмо        блок           процессор          пароль
# 1       номер     рассылка  транзакция              память            флаг
# 2      звонок        адрес  контроллер                ядро           логин
# 3       вызов    подписчик      кнопка  производительность     авторизация
# 4      услуга        почта     ротация             регистр         учётный
# 5    оператор        домен      датчик                  гб         задание
# 6      бизнес     почтовый       плата          инструкция         телефон
# 7     продажа  электронный       длина         архитектура           адрес
# 8  клиентский  отправитель       схема          видеокарта          доступ
# 9  интеграция   получатель     питание             драйвер  аутентификация
#
# [10 rows x 50 columns]

# %% [markdown]
# Часть тем сохраняется (космос, игры, продакшн, базы данных), часть уходит в другие, но слова вроде бы по-прежнему осмысленны друг с другом. Видимо, еще есть запас "ширины" для распределения текстов по темам.

# %%
model3 = NMF(n_components=35)
model3.fit(X)
def get_nmf_topics(model, n_top_words):
    
    #id слов.
    feat_names = vectorizer.get_feature_names()
    
    word_dict = {};
    for i in range(35):
        
        #топ n слов для темы.
        words_ids = model3.components_[i].argsort()[:-n_top_words - 1:-1]
        words = [feat_names[key] for key in words_ids]
        word_dict['Topic # ' + '{:02d}'.format(i+1)] = words;
    
    return pd.DataFrame(word_dict);
get_nmf_topics(model3, 10)
# Out:
#     Topic # 01  Topic # 02 Topic # 03  Topic # 04          Topic # 05  \
# 0      продукт       рынок       игра        файл              память
# 1    сотрудник  российский      игрок       папка           процессор
# 2  программист      страна    игровой      строка                диск
# 3       бизнес      россия     играть      скрипт                ядро
# 4         опыт     миллион   персонаж  директория  производительность
# 5         идея       рубль     движок         имя                  гб
# 6          мой      бизнес   геймплей   программа          накопитель
# 7       деньга       доход  мобильный        флаг         виртуальный
# 8       думать       налог  приставка   запускать              запись
# 9     понимать      деньга       жанр        путь         оперативный
#
#    Topic # 06   Topic # 07    Topic # 08     Topic # 09  Topic # 10  \
# 0       класс  космический        сервер     уязвимость        сайт
# 1      объект      спутник   виртуальный          атака     реклама
# 2       метод       орбита        машина   безопасность    страница
# 3    значение         марс     настройка  злоумышленник       домен
# 4       вызов      аппарат          база    вредоносный     контент
# 5  реализация       ракета       кластер         защита   рекламный
# 6    свойство        земля         домен      атаковать     хостинг
# 7   экземпляр         наса         адрес     обновление  блокировка
# 8  переменный         луна  конфигурация         ботнет    интернет
# 9    параметр      станция          хост       уязвимый  посетитель
#
#       ...       Topic # 26      Topic # 27  Topic # 28  Topic # 29  \
# 0     ...             ключ        облачный        звук       товар
# 1     ...           пароль          облако      сигнал      скидка
# 2     ...        сообщение  инфраструктура     частота     магазин
# 3     ...       шифрование           центр     наушник        цена
# 4     ...            токен            дата   усилитель  распродажа
# 5     ...           запись          сервис    звуковой     покупка
# 6     ...          учётный          услуга  напряжение  покупатель
# 7     ...            адрес     виртуальный   искажение     пятница
# 8     ...          аккаунт              ит      музыка       заказ
# 9     ...          подпись    оборудование         ток       акция
#
#      Topic # 30    Topic # 31     Topic # 32   Topic # 33     Topic # 34  \
# 0       принтер         пакет          робот       камера           сеть
# 1        печать   репозиторий     автомобиль     смартфон         трафик
# 2        станок        сборка         датчик        видео       интернет
# 3      печатать     контейнер         машина        экран          адрес
# 4       пластик        плагин        ребёнок      дисплей          связь
# 5      материал     установка  робототехника  регистратор       протокол
# 6  производство        скрипт       движение      телефон        сетевой
# 7        деталь     настройка           дрон        карта       оператор
# 8        модель  конфигурация    беспилотный           гб          канал
# 9       изделие        запуск            реб       модель  маршрутизатор
#
#     Topic # 35
# 0     обучение
# 1    нейросеть
# 2  изображение
# 3    нейронный
# 4     алгоритм
# 5       модель
# 6     машинный
# 7         сеть
# 8    интеллект
# 9         слой
#
# [10 rows x 35 columns]

# %% [markdown]
# Темы до сих пор осмысленные (только что за реб в теме №32?), распределение примерно то же самое - интернет, базы, современные технологии, космос, сайты и т.д. Пожалуй, учитывая сохранение осмысленности распределения слов, это самое лучшее распределение по темам (т.к. нет слишком узкой специализации).
